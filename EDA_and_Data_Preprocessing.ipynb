# %%
#Importing the libraries - pandas
import pandas as pd

# %% [markdown]
# ## Movie Box Office Dataset

# %%
# Loading the data into Pandas DataFrames
movie_bo = pd.read_csv("Data/Movie Box Office.csv")
movie_bo
# Out:
#      ReleaseDate  Rank                                 Movie  \
# 0     26-04-2019     1                     Avengers: Endgame
# 1     18-12-2015     1  Star Wars Ep. VII: The Force Awakens
# 2     27-05-2022     1                     Top Gun: Maverick
# 3     16-02-2018     1                         Black Panther
# 4     27-04-2018     2                Avengers: Infinity War
# ...          ...   ...                                   ...
# 9828  05-09-2014   810                               Memphis
# 9829  19-11-2015   811                        Paranoid Girls
# 9830  07-11-2014   812                         The Historian
# 9831  05-12-2014   813                               Pioneer
# 9832  09-10-2009   692                 From Mexico with Love
#
#                Distributor              Genre      Gross  Tickets Sold
# 0              Walt Disney             Action  858373000      93708843
# 1              Walt Disney          Adventure  742208942      88043765
# ...

# %%
movie_bo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9833 entries, 0 to 9832
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ReleaseDate   9809 non-null   object
#  1   Rank          9833 non-null   int64
#  2   Movie         9833 non-null   object
#  3   Distributor   9615 non-null   object
#  4   Genre         9734 non-null   object
#  5   Gross         9833 non-null   int64
#  6   Tickets Sold  9833 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 537.9+ KB

# %%
movie_bo.isnull().sum()
# Number of null values in each column:
# Out:
# ReleaseDate      24
# Rank              0
# Movie             0
# Distributor     218
# Genre            99
# Gross             0
# Tickets Sold      0
# dtype: int64

# %%
# Dropping the rows with null values
movie_bo.dropna(subset = ['ReleaseDate'], inplace = True)
movie_bo.isnull().sum()
# Number of null values in each column:
# Out:
# ReleaseDate       0
# Rank              0
# Movie             0
# Distributor     194
# Genre            99
# Gross             0
# Tickets Sold      0
# dtype: int64

# %%
movie_bo.duplicated(subset=['Movie', 'ReleaseDate', 'Rank']).sum()
# Number of repeated columns (Movies):
# Out:
# 7

# %%
# Removing the repeated rows:
movie_bo.drop_duplicates(subset=['Movie', 'ReleaseDate', 'Rank'], inplace=True)
movie_bo.duplicated(subset=['Movie', 'ReleaseDate', 'Rank']).sum()
# Number of repeated columns (Movies):
# Out:
# 0

# %%
# Creating a unique ID and saving the data
movie_bo.to_csv('Data/Movie Box Office.csv')
x = pd.read_csv('Data/Movie Box Office.csv')
x.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
x.to_csv('Data/Movie Box Office.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Movie Industry Dataset

# %%
# Loading the data into Pandas DataFrames
movie_ind = pd.read_csv("Data/Movie Industry.csv")
movie_ind
# Out:
#         Released  year                                            name rating  \
# 0     13-06-1980  1980                                     The Shining      R
# 1     02-07-1980  1980                                 The Blue Lagoon      R
# 2     20-06-1980  1980  Star Wars: Episode V - The Empire Strikes Back     PG
# 3     02-07-1980  1980                                       Airplane!     PG
# 4     25-07-1980  1980                                      Caddyshack      R
# ...          ...   ...                                             ...    ...
# 7663  23-10-2020  2020                                    More to Life    NaN
# 7664  07-02-2020  2020                                     Dream Round    NaN
# 7665  27-04-2020  2020                                   Saving Mbango    NaN
# 7666  01-10-2020  2020                                    It's Just Us    NaN
# 7667  19-08-2020  2020                                       Tee em el    NaN
#
# ...

# %%
movie_ind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Released  7609 non-null   object
#  1   year      7668 non-null   int64
#  2   name      7668 non-null   object
#  3   rating    7591 non-null   object
#  4   genre     7668 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
movie_ind.isnull().sum()
# Number of null values in each column:
# Out:
# Released      59
# year           0
# name           0
# rating        77
# genre          0
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
# Dropping the rows with null values
movie_ind.dropna(subset = ['Released', 'rating', 'budget'], inplace = True)
movie_ind.isnull().sum()
# Number of null values in each column:
# Out:
# Released     0
# year         0
# name         0
# rating       0
# genre        0
# score        1
# votes        1
# director     0
# writer       0
# star         0
# country      0
# budget       0
# gross       51
# company      2
# runtime      1
# dtype: int64

# %%
movie_ind.duplicated(subset=['name', 'Released']).sum()
# Number of repeated columns (Movies):
# Out:
# 0

# %%
# Saving the data
movie_ind.to_csv('Data/Movie Industry.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Movie Dataset

# %%
# Loading the data into Pandas DataFrames
movie_df = pd.read_csv("Data/movie_dataset.csv")
movie_df
# Out:
#      release_date                                     title  runtime  \
# 0      10-12-2009                                    Avatar    162.0
# 1      19-05-2007  Pirates of the Caribbean: At World's End    169.0
# 2      26-10-2015                                   Spectre    148.0
# 3      16-07-2012                     The Dark Knight Rises    165.0
# 4      07-03-2012                               John Carter    132.0
# ...           ...                                       ...      ...
# 4795   04-09-1992                               El Mariachi     81.0
# 4796   26-12-2011                                 Newlyweds     85.0
# 4797   13-10-2013                 Signed, Sealed, Delivered    120.0
# 4798   03-05-2012                          Shanghai Calling     98.0
# 4799   05-08-2005                         My Date with Drew     90.0
#
#                                                 tagline  vote_average  \
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4800 entries, 0 to 4799
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   release_date  4799 non-null   object
#  1   title         4800 non-null   object
#  2   runtime       4798 non-null   float64
#  3   tagline       3956 non-null   object
#  4   vote_average  4800 non-null   float64
#  5   vote_count    4800 non-null   int64
#  6   director      4764 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 262.6+ KB

# %%
movie_df.isnull().sum()
# Number of null values in each column:
# Out:
# release_date      1
# title             0
# runtime           2
# tagline         844
# vote_average      0
# vote_count        0
# director         36
# dtype: int64

# %%
# Dropping the rows with null values
movie_df.dropna(subset = ['release_date', 'title'], inplace = True)
movie_df.isnull().sum()
# Number of null values in each column:
# Out:
# release_date      0
# title             0
# runtime           2
# tagline         843
# vote_average      0
# vote_count        0
# director         35
# dtype: int64

# %%
movie_df.duplicated(subset=['release_date', 'title']).sum()
# Number of repeated columns (Movies):
# Out:
# 0

# %%
# Saving the data
movie_df.to_csv('Data/movie_dataset.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Streaming Titles Dataset

# %%
# Loading the data into Pandas DataFrames
streaming_df = pd.read_csv("Data/streaming_titles.csv", encoding='latin1')
streaming_df
# Out:
#                                                    type  \
# 0                                                 Movie
# 1                                               TV Show
# 2                                               TV Show
# 3                                               TV Show
# 4                                               TV Show
# ...                                                 ...
# 9634                          who plays Edgar Quintero
# 9635   DAS BOOT explores the emotional torment of ...
# 9636   brought on by the sudden death of their fathe...
# 9637   the early days of many renowned Zeon ace pilo...
# 9638                                   Mail Order Wife)
#
#                                                   title  \
# 0                                  Dick Johnson Is Dead
# 1                                         Blood & Water
# 2                                             Ganglands
# 3                                 Jailbirds New Orleans
# ...

# %% [markdown]
# From the above, seems like some data got wrapped into the following rows. Let's clean it by removing null values first...

# %%
streaming_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9639 entries, 0 to 9638
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          9638 non-null   object
#  1   title         9638 non-null   object
#  2   country       8011 non-null   object
#  3   date_added    8823 non-null   object
#  4   release_year  9629 non-null   float64
#  5   rating        9625 non-null   object
#  6   listed_in     9629 non-null   object
#  7   Platform      9639 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 602.6+ KB

# %%
streaming_df.isnull().sum()
# Number of null values in each column:
# Out:
# type               1
# title              1
# country         1628
# date_added       816
# release_year      10
# rating            14
# listed_in         10
# Platform           0
# dtype: int64

# %%
# Dropping the rows with null values
streaming_df.dropna(subset = ['type', 'title', 'date_added'], inplace = True)
streaming_df.isnull().sum()
# Number of null values in each column:
# Out:
# type              0
# title             0
# country         857
# date_added        0
# release_year      0
# rating            4
# listed_in         0
# Platform          0
# dtype: int64

# %%
# Checking for the wrapped data
streaming_df
# Out:
#          type                                  title        country  \
# 0       Movie                   Dick Johnson Is Dead  United States
# 1     TV Show                          Blood & Water   South Africa
# 2     TV Show                              Ganglands            NaN
# 3     TV Show                  Jailbirds New Orleans            NaN
# 4     TV Show                           Kota Factory          India
# ...       ...                                    ...            ...
# 9506  TV Show                            Pan y Circo            NaN
# 9514  TV Show                        Hidden Villages            NaN
# 9600  TV Show  Pokémon the Series: Diamond and Pearl            NaN
# 9607  TV Show                            Lunkerville            NaN
# 9612  TV Show                       Kids In The Hall            NaN
#
#       date_added  release_year rating  \
# 0     25-09-2021        2020.0  PG-13
# 1     24-09-2021        2021.0  TV-MA
# ...

# %%
set(streaming_df['type'])
# Out:
# {'Movie', 'TV Show'}

# %% [markdown]
# The wrapped data is now cleaned and only Movies and TV Shows remain.

# %%
streaming_df.duplicated(subset=['type', 'title', 'date_added']).sum()
# Number of repeated columns (Movies):
# Out:
# 0

# %%
# Saving the data
streaming_df.to_csv('Data/streaming_titles.csv', encoding='utf-8', index=False)
